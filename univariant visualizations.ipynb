# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [raw]
# BAR graphs

# %%
df=pd.read_csv("cleaned_NYC.csv")

# %%
df
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
sns.countplot(data=df,x="neighbourhood_group",hue="room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [raw]
# This will show the distribution of room types within each neighborhood group, providing a more granular view of how room types are spread across different neighborhoods in New York City.

# %% [raw]
# Pie Charts

# %%
df["neighbourhood_group"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["room_type"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
This pie chart will display the percentage of hotels with each room type

# %% [raw]
# Histogram: Visualizing Frequency Distribution

# %%
sns.histplot(df["price"],color="orange")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [raw]
# The bars represent different price ranges, and the height of the bars shows how many hotels fall within each price range. Since the dataset is likely to contain a wide range of prices, it may be skewed due to a small number of very expensive listings.

# %% [raw]
#  Filtering Values for a Clearer Distribution

# %%
sns.histplot(df[df["price"]<500]["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [raw]
# Distplot for price Column

# %%
sns.distplot(df["price"])
# Out:
# C:\Users\venna\AppData\Local\Temp\ipykernel_25164\50337492.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %% [raw]
# Box Plot for price Column
# Let’s create a box plot for the price column to understand the distribution and identify any potential outliers

# %%
sns.boxplot(df[df["price"]<500]["price"])
# Out:
# <Axes: ylabel='price'>

# %% [raw]
# This box plot will show the interquartile range (IQR) of prices, with the box representing the 25th to 75th percentiles, the line within the box indicating the median, and the "whiskers" extending to the minimum and maximum values (excluding outliers). Any values outside the whiskers are considered outliers.
